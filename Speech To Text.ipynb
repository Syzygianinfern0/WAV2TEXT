# %%
import IPython.display as ipd
ipd.Audio('data/speech.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !./speech_to_text.sh
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     155             else:
# --> 156                 child = pexpect.spawn(self.sh, args=['-c', cmd])  # Vanilla Pexpect
#     157             flush = sys.stdout.flush
#
# /usr/local/lib/python3.6/dist-packages/pexpect/pty_spawn.py in __init__(self, command, args, timeout, maxread, searchwindowsize, logfile, cwd, env, ignore_sighup, echo, preexec_fn, encoding, codec_errors, dimensions, use_poll)
#     204         else:
# --> 205             self._spawn(command, args, preexec_fn, dimensions)
#     206         self.use_poll = use_poll
#
# /usr/local/lib/python3.6/dist-packages/pexpect/pty_spawn.py in _spawn(self, command, args, preexec_fn, dimensions)
#     303         self.ptyproc = self._spawnpty(self.args, env=self.env,
# ...

# %%
with open('decoded_text', 'rb') as handler:
    text = handler.read().decode('utf-8')
print(text)
# Out:
# जिन्हें मेरा भारत महान
